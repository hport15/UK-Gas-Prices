# %% [markdown]
# <a href="https://colab.research.google.com/github/hport15/UK-Gas-Prices/blob/main/Data_Visualization_Exercise_(Practice).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
filename = '/content/drive/MyDrive/Data Science/Data/Weekly Fuel Prices.xlsx'
df = pd.read_excel(filename)
df
# Out:
#                         Date  Petrol (USD)  Diesel (USD)
# 0        2003-06-09 00:00:00     74.590284     76.773394
# 1        2003-06-16 00:00:00     74.469143     76.689054
# 2        2003-06-23 00:00:00     74.423566     76.620546
# 3        2003-06-30 00:00:00     74.352421     76.505260
# 4        2003-07-07 00:00:00     74.283737     76.457376
# ..                       ...           ...           ...
# 878      2020-04-06 00:00:00    110.234797    116.833354
# 879      2020-04-13 00:00:00    109.265819    116.150812
# 880      2020-04-20 00:00:00    108.632747    115.732573
# 881                      NaN           NaN           NaN
# 882  Return to Contents page           NaN           NaN
#
# [883 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          882 non-null    object
#  1   Petrol (USD)  881 non-null    float64
#  2   Diesel (USD)  881 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 20.8+ KB

# %% [markdown]
# The missing rows were irrelevant so dropped.

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 0 to 880
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          881 non-null    object
#  1   Petrol (USD)  881 non-null    float64
#  2   Diesel (USD)  881 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 27.5+ KB

# %%
from numpy.ma.core import size
plt.figure(figsize=(20,10))
plt.plot(df['Date'],df['Petrol (USD)'],marker='s', markersize=3, c='c', label='Gas')
plt.plot(df['Date'],df['Diesel (USD)'],marker='o',c='k',markersize=3, label='Diesel')
plt.xlabel('Date',fontsize=14)
plt.ylabel('Prices in USD',fontsize=14)
plt.title('UK Gas Prices Over Time',fontsize=16)
plt.grid(c='b',alpha=.2)
plt.tight_layout()
plt.legend()
plt.savefig('UKgasdiesel.png', dpi = 300);
